# %% [markdown]
# <a href="https://colab.research.google.com/github/MDankloff/Cluster-Bias-Disco/blob/main/MLGymTryOut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation instructions

# %%
#!rm -rf ml-fairness-gym

# %%
# !git clone https://github.com/google/ml-fairness-gym && \
cd /content/ml-fairness-gym && \
sed -i 's/sklearn/scikit-learn/' requirements.txt
# Out:
# Cloning into 'ml-fairness-gym'...
# remote: Enumerating objects: 534, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 534 (delta 19), reused 22 (delta 2), pack-reused 417 (from 1)
# Receiving objects: 100% (534/534), 7.29 MiB | 9.87 MiB/s, done.
# Resolving deltas: 100% (263/263), done.

# %%
#downgrade setuptools to fix compatability issues for gym == 0.19.0 with newer versions of setuptools
# !pip install setuptools==57.5.0
# Out:
# Requirement already satisfied: setuptools==57.5.0 in /usr/local/lib/python3.10/dist-packages (57.5.0)

# %%
#downgrading pip as well
# !python -m pip install "pip>=23.0,<24.0"
# Out:
# Collecting pip<24.0,>=23.0
#   Downloading pip-23.3.2-py3-none-any.whl.metadata (3.5 kB)
# Downloading pip-23.3.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 29.0 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-23.3.2

# %%
#The version gym==0.19.0 has some metadata issues. We'll download the source, extract it, and modify the setup.py file to fix the opencv-python dependency
# !pip download gym==0.19.0
# !tar -xzf gym-0.19.0.tar.gz
# %cd gym-0.19.0
# !sed -i 's/opencv-python>=3./opencv-python>=3.0.0/' setup.py
# Out:
# Collecting gym==0.19.0
#   Downloading gym-0.19.0.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numpy>=1.18.0 (from gym==0.19.0)
#   Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.4 MB/s eta 0:00:00
# Collecting cloudpickle<1.7.0,>=1.2.0 (from gym==0.19.0)
#   Downloading cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 53.5 MB/s eta 0:00:00
# Saved ./gym-0.19.0.tar.gz
# Saved ./cloudpickle-1.6.0-py3-none-any.whl
# Saved ./numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Successfully downloaded gym cloudpickle numpy
# /content/gym-0.19.0

# %%
#install remaining dependencies from the requirements.txt file
# !pip install -r /content/ml-fairness-gym/requirements.txt
# Out:
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 1)) (1.4.0)
# Collecting atari-py (from -r /content/ml-fairness-gym/requirements.txt (line 2))
#   Downloading atari-py-0.2.9.tar.gz (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.6/540.6 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 3)) (24.2.0)
# Requirement already satisfied: dopamine-rl in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 4)) (4.0.9)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 5)) (0.5.0)
# Collecting gym==0.19.0 (from -r /content/ml-fairness-gym/requirements.txt (line 6))
#   Using cached gym-0.19.0.tar.gz (1.6 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 7)) (3.8.0)
# Collecting monty (from -r /content/ml-fairness-gym/requirements.txt (line 8))
#   Downloading monty-2024.10.21-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 9)) (10.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 11)) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 12)) (2.2.2)
# Collecting recsim (from -r /content/ml-fairness-gym/requirements.txt (line 13))
#   Downloading recsim-0.2.4.tar.gz (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 14)) (0.13.2)
# Collecting simplejson (from -r /content/ml-fairness-gym/requirements.txt (line 15))
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 16)) (1.5.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 17)) (0.14.4)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 18)) (2.17.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r /content/ml-fairness-gym/requirements.txt (line 19)) (4.66.6)
# Collecting cloudpickle<1.7.0,>=1.2.0 (from gym==0.19.0->-r /content/ml-fairness-gym/requirements.txt (line 6))
#   Using cached cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from atari-py->-r /content/ml-fairness-gym/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: opencv-python>=3.4.8.29 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (4.10.0.84)
# Requirement already satisfied: flax>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: jax>=0.1.72 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.4.33)
# Requirement already satisfied: jaxlib>=0.1.51 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.4.33)
# Requirement already satisfied: Pillow>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (11.0.0)
# Requirement already satisfied: pygame>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: tf-slim>=1.0 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: tensorflow-probability>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ml-fairness-gym/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ml-fairness-gym/requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ml-fairness-gym/requirements.txt (line 7)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ml-fairness-gym/requirements.txt (line 7)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ml-fairness-gym/requirements.txt (line 7)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ml-fairness-gym/requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ml-fairness-gym/requirements.txt (line 7)) (2.8.2)
# Collecting ruamel.yaml (from monty->-r /content/ml-fairness-gym/requirements.txt (line 8))
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r /content/ml-fairness-gym/requirements.txt (line 12)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->-r /content/ml-fairness-gym/requirements.txt (line 12)) (2024.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from recsim->-r /content/ml-fairness-gym/requirements.txt (line 13)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r /content/ml-fairness-gym/requirements.txt (line 16)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r /content/ml-fairness-gym/requirements.txt (line 16)) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->-r /content/ml-fairness-gym/requirements.txt (line 17)) (1.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (57.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.45.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.1.68)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.1.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.13.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.13.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.1.8)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->monty->-r /content/ml-fairness-gym/requirements.txt (line 8))
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->-r /content/ml-fairness-gym/requirements.txt (line 18)) (3.0.2)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.10/dist-packages (from optax->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.1.87)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.10/dist-packages (from optax->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (1.10.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (4.11.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.87->optax->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.2.0->dopamine-rl->-r /content/ml-fairness-gym/requirements.txt (line 4)) (3.21.0)
# Downloading monty-2024.10.21-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 5.0 MB/s eta 0:00:00
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 8.9 MB/s eta 0:00:00
# Using cached cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 8.0 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 13.7 MB/s eta 0:00:00
# Building wheels for collected packages: gym, atari-py, recsim
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for gym (setup.py) ... error
#   ERROR: Failed building wheel for gym
#   Running setup.py clean for gym
#   Building wheel for atari-py (setup.py) ... done
#   Created wheel for atari-py: filename=atari_py-0.2.9-cp310-cp310-linux_x86_64.whl size=2870763 sha256=f3cd3fecd015784c4ed94d410575fc10b098a169a9e4acfd0beab57eaf530dbc
#   Stored in directory: /root/.cache/pip/wheels/75/6f/04/1f3bf5255580101e16ff487564354dddcdd23ec3b43b775b7a
#   Building wheel for recsim (setup.py) ... done
#   Created wheel for recsim: filename=recsim-0.2.4-py3-none-any.whl size=105525 sha256=f1fb7d5168fda39dfc9f163936a7e14552670e6a0fb5a270555f7288382ed29e
#   Stored in directory: /root/.cache/pip/wheels/4f/d4/cc/7a58573c6229c78257d5faff372069f52269ca888144c77ed3
# Successfully built atari-py recsim
# Failed to build gym
# ERROR: Could not build wheels for gym, which is required to install pyproject.toml-based projects

# %% [markdown]
# # Set up Environment Variable

# %%
#Need to update the PYTHONPATH so that Colab recognize the ml-fairness-gym package:
import os
os.environ['PYTHONPATH'] = f"{os.environ.get('PYTHONPATH', '')}:/content/ml-fairness-gym"

# %%
# !echo $PYTHONPATH
# Out:
# /env/python:/content/ml-fairness-gym

# %%
#fix tensorflow compatibility
# !pip install tensorflow==2.14
# Out:
# Collecting tensorflow==2.14
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (18.1.1)
# Collecting ml-dtypes==0.2.0 (from tensorflow==2.14)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (57.5.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.14)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.68.0)
# Collecting tensorboard<2.15,>=2.14 (from tensorflow==2.14)
#   Downloading tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow==2.14)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.15,>=2.14.0 (from tensorflow==2.14)
#   Downloading keras-2.14.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.14) (0.45.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (2.27.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.15,>=2.14->tensorflow==2.14)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14) (3.2.2)
# Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 1.2 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.8 MB/s eta 0:00:00
# Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 58.3 MB/s eta 0:00:00
# Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 66.5 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 24.9 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.4 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.68 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed google-auth-oauthlib-1.0.0 keras-2.14.0 ml-dtypes-0.2.0 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0 wrapt-1.14.1

# %% [markdown]
# # Run the tests

# %%
# !cd /content/ml-fairness-gym
# !chmod +x tests.sh
# !./tests.sh
# Out:
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] ParamsTest.test_as_array
# [       OK ] ParamsTest.test_as_array
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/rewards_test.py", line 22, in <module>
#     import rewards
#   File "/content/ml-fairness-gym/rewards.py", line 27, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# /usr/local/lib/python3.10/dist-packages/tensorflow/__init__.py:29: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils as _distutils
# 2024-11-28 13:03:40.728614: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:03:40.793919: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:03:40.794073: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:03:40.794230: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:03:40.810898: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:03:40.811627: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes
# 2024-11-28 13:03:42.266490: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:51: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/infectious_disease_rl_test.py", line 24, in <module>
#     from experiments import infectious_disease_rl
#   File "/content/ml-fairness-gym/experiments/infectious_disease_rl.py", line 29, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# 2024-11-28 13:03:46.572019: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:03:46.619686: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:03:46.619750: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:03:46.619798: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:03:46.630197: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:03:46.630500: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 13:03:48.110996: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/lending_plots_test.py", line 25, in <module>
#     from experiments import lending
#   File "/content/ml-fairness-gym/experiments/lending.py", line 24, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/attention_allocation_experiment_test.py", line 23, in <module>
#     from agents import allocation_agents
#   File "/content/ml-fairness-gym/agents/allocation_agents.py", line 28, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/infectious_disease_test.py", line 24, in <module>
#     from experiments import infectious_disease
#   File "/content/ml-fairness-gym/experiments/infectious_disease.py", line 24, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/lending_test.py", line 24, in <module>
#     from experiments import lending
#   File "/content/ml-fairness-gym/experiments/lending.py", line 24, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/college_admission_test.py", line 27, in <module>
#     from experiments import college_admission
#   File "/content/ml-fairness-gym/experiments/college_admission.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# 2024-11-28 13:03:54.306600: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:03:54.356408: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:03:54.356471: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:03:54.356524: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:03:54.365527: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:03:54.365885: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 13:03:55.803328: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/movielens_recs_test.py", line 26, in <module>
#     from environments.recommenders import movie_lens_dynamic
#   File "/content/ml-fairness-gym/environments/recommenders/movie_lens_dynamic.py", line 37, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/experiments/college_admission_util_test.py", line 23, in <module>
#     import runner_lib
#   File "/content/ml-fairness-gym/runner_lib.py", line 29, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/attention_allocation_test.py", line 24, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/template_test.py", line 23, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/recommenders/restaurant_toy_recsim_test.py", line 23, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# 2024-11-28 13:04:01.164811: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:01.216621: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:04:01.216693: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:04:01.216759: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:04:01.226364: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:01.226696: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 13:04:02.942107: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/recommenders/movie_lens_dynamic_test.py", line 26, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] DownloadMovielensTest.test_pandas_bytes_behavior
# /content/ml-fairness-gym/environments/recommenders/download_movielens_test.py:31: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   _ = pd.read_csv(f, sep='::', encoding='iso-8859-1')
# [       OK ] DownloadMovielensTest.test_pandas_bytes_behavior
# ----------------------------------------------------------------------
# Ran 1 test in 0.012s
#
# OK
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/recommenders/recsim_wrapper_test.py", line 24, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/infectious_disease_test.py", line 22, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/lending_test.py", line 25, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/environments/college_admission_test.py", line 22, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/runner_lib_test.py", line 22, in <module>
#     import core  # pylint: disable=unused-import
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/metrics/error_metrics_test.py", line 23, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/metrics/lending_metrics_test.py", line 22, in <module>
#     import rewards
#   File "/content/ml-fairness-gym/rewards.py", line 27, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/metrics/infectious_disease_metrics_test.py", line 21, in <module>
#     from environments import infectious_disease
#   File "/content/ml-fairness-gym/environments/infectious_disease.py", line 36, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/metrics/distribution_comparison_metrics_test.py", line 23, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/metrics/value_tracking_metrics_test.py", line 24, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/core_test.py", line 27, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] GraphTest.test_sampled_graphs_contain_correct_number_of_nodes
# [       OK ] GraphTest.test_sampled_graphs_contain_correct_number_of_nodes
# [ RUN      ] GraphTest.test_undirected_space_not_equal_to_directed_space
# [       OK ] GraphTest.test_undirected_space_not_equal_to_directed_space
# ----------------------------------------------------------------------
# Ran 2 tests in 0.006s
#
# OK
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] MultinomialTest.test_contains_correct
# [       OK ] MultinomialTest.test_contains_correct
# [ RUN      ] MultinomialTest.test_contains_correct_n_in_vector
# [       OK ] MultinomialTest.test_contains_correct_n_in_vector
# [ RUN      ] MultinomialTest.test_contains_incorrect_dtype
# [       OK ] MultinomialTest.test_contains_incorrect_dtype
# [ RUN      ] MultinomialTest.test_contains_incorrect_length
# [       OK ] MultinomialTest.test_contains_incorrect_length
# [ RUN      ] MultinomialTest.test_contains_incorrect_sum
# [       OK ] MultinomialTest.test_contains_incorrect_sum
# [ RUN      ] MultinomialTest.test_contains_samples
# [       OK ] MultinomialTest.test_contains_samples
# [ RUN      ] MultinomialTest.test_sample_distribution
# [       OK ] MultinomialTest.test_sample_distribution
# [ RUN      ] MultinomialTest.test_sample_sum
# [       OK ] MultinomialTest.test_sample_sum
# ----------------------------------------------------------------------
# Ran 8 tests in 0.007s
#
# OK
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] BatchTest.test_batches_are_contained_in_space
# [       OK ] BatchTest.test_batches_are_contained_in_space
# ----------------------------------------------------------------------
# Ran 1 test in 0.004s
#
# OK
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] MultiDiscreteWithNoneTest.test_base_and_with_none_agree
# [       OK ] MultiDiscreteWithNoneTest.test_base_and_with_none_agree
# [ RUN      ] MultiDiscreteWithNoneTest.test_none_can_be_sampled
# /usr/local/lib/python3.10/dist-packages/gym/utils/seeding.py:41: DeprecationWarning: WARN: Function `rng.rand(*size)` is marked as deprecated and will be removed in the future. Please use `Generator.random(size)` instead.
#   deprecation(
# [       OK ] MultiDiscreteWithNoneTest.test_none_can_be_sampled
# [ RUN      ] MultiDiscreteWithNoneTest.test_space_contains_none
# [       OK ] MultiDiscreteWithNoneTest.test_space_contains_none
# ----------------------------------------------------------------------
# Ran 3 tests in 0.001s
#
# OK
# 2024-11-28 13:04:14.969226: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:15.019209: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:04:15.019275: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:04:15.019324: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:04:15.028565: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:15.028926: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 13:04:16.913883: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] UtilitiesTest.test_delete_recursively
# [       OK ] UtilitiesTest.test_delete_recursively
# [ RUN      ] UtilitiesTest.test_makedirs
# [       OK ] UtilitiesTest.test_makedirs
# [ RUN      ] UtilitiesTest.test_read_write_files
# [       OK ] UtilitiesTest.test_read_write_files
# ----------------------------------------------------------------------
# Ran 3 tests in 0.003s
#
# OK
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] DistributionsTest.test_bernoulli_returns_proportionally
# [       OK ] DistributionsTest.test_bernoulli_returns_proportionally
# [ RUN      ] DistributionsTest.test_constant_returns_the_same_thing
# [       OK ] DistributionsTest.test_constant_returns_the_same_thing
# [ RUN      ] DistributionsTest.test_gaussian_has_right_mean_std
# [       OK ] DistributionsTest.test_gaussian_has_right_mean_std
# [ RUN      ] DistributionsTest.test_improper_distributions_raise_errors
# [       OK ] DistributionsTest.test_improper_distributions_raise_errors
# [ RUN      ] DistributionsTest.test_mixture_returns_components
# [       OK ] DistributionsTest.test_mixture_returns_components
# ----------------------------------------------------------------------
# Ran 5 tests in 0.055s
#
# OK
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/oracle_lending_agent_test.py", line 24, in <module>
#     import rewards
#   File "/content/ml-fairness-gym/rewards.py", line 27, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/infectious_disease_agents_test.py", line 24, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# 2024-11-28 13:04:22.086815: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:22.136558: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:04:22.136646: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:04:22.136703: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:04:22.148887: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:22.149286: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 13:04:23.600363: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/recommenders/batched_movielens_rnn_agent_test.py", line 24, in <module>
#     from agents.recommenders import batched_movielens_rnn_agent
#   File "/content/ml-fairness-gym/agents/recommenders/batched_movielens_rnn_agent.py", line 23, in <module>
#     from agents.recommenders import rnn_cvar_agent
#   File "/content/ml-fairness-gym/agents/recommenders/rnn_cvar_agent.py", line 20, in <module>
#     from agents.recommenders import rnn_agent
#   File "/content/ml-fairness-gym/agents/recommenders/rnn_agent.py", line 28, in <module>
#     import recsim
# ModuleNotFoundError: No module named 'recsim'
# 2024-11-28 13:04:26.856617: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:26.905335: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:04:26.905397: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:04:26.905450: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:04:26.914711: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:26.915038: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 13:04:28.399897: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/recommenders/evaluation_test.py", line 26, in <module>
#     from agents.recommenders import rnn_cvar_agent
#   File "/content/ml-fairness-gym/agents/recommenders/rnn_cvar_agent.py", line 20, in <module>
#     from agents.recommenders import rnn_agent
#   File "/content/ml-fairness-gym/agents/recommenders/rnn_agent.py", line 28, in <module>
#     import recsim
# ModuleNotFoundError: No module named 'recsim'
# 2024-11-28 13:04:34.250277: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:34.304256: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-28 13:04:34.304331: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-28 13:04:34.304381: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 13:04:34.314307: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 13:04:34.314676: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 13:04:35.659882: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/recommenders/model_test.py", line 20, in <module>
#     from agents.recommenders import batched_movielens_rnn_agent
#   File "/content/ml-fairness-gym/agents/recommenders/batched_movielens_rnn_agent.py", line 23, in <module>
#     from agents.recommenders import rnn_cvar_agent
#   File "/content/ml-fairness-gym/agents/recommenders/rnn_cvar_agent.py", line 20, in <module>
#     from agents.recommenders import rnn_agent
#   File "/content/ml-fairness-gym/agents/recommenders/rnn_agent.py", line 28, in <module>
#     import recsim
# ModuleNotFoundError: No module named 'recsim'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/classifier_agents_test.py", line 26, in <module>
#     import rewards
#   File "/content/ml-fairness-gym/rewards.py", line 27, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/random_agents_test.py", line 24, in <module>
#     import test_util
#   File "/content/ml-fairness-gym/test_util.py", line 25, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/allocation_agents_test.py", line 24, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ml-fairness-gym/agents/college_admission_jury_test.py", line 21, in <module>
#     import core
#   File "/content/ml-fairness-gym/core.py", line 33, in <module>
#     import gym.utils.json_utils
# ModuleNotFoundError: No module named 'gym.utils.json_utils'
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] ThresholdPoliciesTest.test_convex_hull_roc
# [       OK ] ThresholdPoliciesTest.test_convex_hull_roc
# [ RUN      ] ThresholdPoliciesTest.test_equality_of_opportunity_holds
# [       OK ] ThresholdPoliciesTest.test_equality_of_opportunity_holds
# [ RUN      ] ThresholdPoliciesTest.test_reward_is_maximized
# [       OK ] ThresholdPoliciesTest.test_reward_is_maximized
# [ RUN      ] ThresholdPoliciesTest.test_weighted_single_threshold
# [       OK ] ThresholdPoliciesTest.test_weighted_single_threshold
# ----------------------------------------------------------------------
# Ran 4 tests in 13.467s
#
# OK

# %% [markdown]
# # Run the simulation

# %%
# !cd /content/ml-fairness-gym
# !ls /content/ml-fairness-gym/experiments/lending_demo.py
# !python /content/ml-fairness-gym/experiments/lending_demo.py --num_steps=5000
# Out:
# /content/ml-fairness-gym/experiments/lending_demo.py
#   File "/content/ml-fairness-gym/experiments/lending_demo.py", line 25
#     from ml-fairness-gym.agents import threshold_policies
#            ^
# SyntaxError: invalid syntax
